# %%
import numpy as np

# from IPython.core.debugger import Tracer

from keras.datasets import mnist
from keras.layers import Input, Dense, Reshape, Flatten, Dropout
from keras.layers import BatchNormalization
from keras.layers.advanced_activations import LeakyReLU
from keras.models import Sequential
from keras.optimizers import Adam

# import matplotlib as plt
import matplotlib.pyplot as plt 
# plt.switch_backend('agg')   # allows code to run without a system DISPLAY

# %%
class GAN(object):
    def __init__(self, width=28, height=28, channels=1):

        self.width = width
        self.height = height
        self.channels = channels

        self.shape = (self.width, self.height, self.channels)

        self.optimizer = Adam(lr=0.0002, beta_1=0.5, decay=8e-8)

        self.G = self.__generator()
        self.G.compile(loss='binary_crossentropy', optimizer=self.optimizer)

        self.D = self.__discriminator()
        self.D.compile(loss='binary_crossentropy', optimizer=self.optimizer, metrics=['accuracy'])

        self.stacked_generator_discriminator = self.__stacked_generator_discriminator()

        self.stacked_generator_discriminator.compile(loss='binary_crossentropy', optimizer=self.optimizer)

    def __generator(self):
        model = Sequential()
        model.add(Dense(256, input_shape=(100,)))
        model.add(LeakyReLU(alpha=0.2))  # 使用 LeakyReLU 激活函數
        model.add(BatchNormalization(momentum=0.8))  # 使用 BatchNormalization 優化
        model.add(Dense(512))
        model.add(LeakyReLU(alpha=0.2))
        model.add(BatchNormalization(momentum=0.8))
        model.add(Dense(1024))
        model.add(LeakyReLU(alpha=0.2))
        model.add(BatchNormalization(momentum=0.8))
        model.add(Dense(self.width  * self.height * self.channels, activation='tanh'))
        model.add(Reshape((self.width, self.height, self.channels)))
        model.summary()

        return model
    def __discriminator(self):
        model = Sequential()
        model.add(Flatten(input_shape=self.shape))
        model.add(Dense((self.width * self.height * self.channels), input_shape=self.shape))
        model.add(LeakyReLU(alpha=0.2))
        model.add(Dense(int((self.width * self.height * self.channels)/2)))
        model.add(LeakyReLU(alpha=0.2))
        model.add(Dense(1, activation='sigmoid'))
        model.summary()

        return model

    def __stacked_generator_discriminator(self):

        self.D.trainable = False

        model = Sequential()
        model.add(self.G)
        model.add(self.D)

        return model

    def train(self, X_train, epochs=30000, batch = 32, save_interval = 100):

        for cnt in range(epochs):

            ## train discriminator
            random_index = np.random.randint(0, len(X_train) - batch/2)
            legit_images = X_train[random_index : random_index + int(batch/2)].reshape(int(batch/2), self.width, self.height, self.channels)

            gen_noise = np.random.normal(0, 1, (int(batch/2), 100)) 
            syntetic_images = self.G.predict(gen_noise)

            x_combined_batch = np.concatenate((legit_images, syntetic_images))
            y_combined_batch = np.concatenate((np.ones((int(batch/2), 1)), np.zeros((int(batch/2), 1))))

            d_loss = self.D.train_on_batch(x_combined_batch, y_combined_batch)


            # train generator

            noise = np.random.normal(0, 1, (batch, 100))  # 添加高斯噪聲
            y_mislabled = np.ones((batch, 1))

            g_loss = self.stacked_generator_discriminator.train_on_batch(noise, y_mislabled)
            if cnt % save_interval == 0:
                print ('epoch: %d, [Discriminator :: d_loss: %f], [ Generator :: loss: %f]' % (cnt, d_loss[0], g_loss))
                self.stacked_generator_discriminator.save("model.h5")
                self.plot_images(save2file=True, step=cnt)
    def plot_images(self, save2file=False, samples=16, step=0):
        filename = "mnist_%s.png" % str(step).zfill(5)
        noise = np.random.normal(0, 1, (samples, 100))

        images = self.G.predict(noise)

        # plt.figure(figsize=(10, 10))

        for i in range(images.shape[0]):
            plt.subplot(4, 4, i+1)
            image = images[i, :, :, :]
            image = np.reshape(image, [self.height, self.width])
            plt.imshow(image, cmap='gray')
            plt.axis('off')
        plt.tight_layout()

        if save2file:
            plt.savefig(filename)
            plt.close('all')
        else:
            plt.show()

# %%
if __name__ == '__main__':
    (X_train, _), (_, _) = mnist.load_data()

    # Rescale -1 to 1
    X_train = (X_train.astype(np.float32) - 127.5) / 127.5
    X_train = np.expand_dims(X_train, axis=3)


    gan = GAN()
    gan.train(X_train)
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_7 (Dense)              (None, 256)               25856
# _________________________________________________________________
# leaky_re_lu_5 (LeakyReLU)    (None, 256)               0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 256)               1024
# _________________________________________________________________
# dense_8 (Dense)              (None, 512)               131584
# _________________________________________________________________
# leaky_re_lu_6 (LeakyReLU)    (None, 512)               0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 512)               2048
# _________________________________________________________________
# dense_9 (Dense)              (None, 1024)              525312
# _________________________________________________________________
# leaky_re_lu_7 (LeakyReLU)    (None, 1024)              0
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 1024)              4096
# _________________________________________________________________
# dense_10 (Dense)             (None, 784)               803600
# _________________________________________________________________
# reshape_1 (Reshape)          (None, 28, 28, 1)         0
# =================================================================
# Total params: 1,493,520
# Trainable params: 1,489,936
# Non-trainable params: 3,584
# _________________________________________________________________
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 784)               615440
# _________________________________________________________________
# leaky_re_lu_8 (LeakyReLU)    (None, 784)               0
# _________________________________________________________________
# dense_12 (Dense)             (None, 392)               307720
# _________________________________________________________________
# leaky_re_lu_9 (LeakyReLU)    (None, 392)               0
# _________________________________________________________________
# dense_13 (Dense)             (None, 1)                 393
# =================================================================
# Total params: 923,553
# Trainable params: 923,553
# Non-trainable params: 0
# _________________________________________________________________
# epoch: 0, [Discriminator :: d_loss: 0.659277], [ Generator :: loss: 0.813102]
# epoch: 100, [Discriminator :: d_loss: 0.014466], [ Generator :: loss: 5.532363]
# epoch: 200, [Discriminator :: d_loss: 0.081453], [ Generator :: loss: 3.500382]
# epoch: 300, [Discriminator :: d_loss: 0.478845], [ Generator :: loss: 0.850719]
# epoch: 400, [Discriminator :: d_loss: 0.709216], [ Generator :: loss: 0.385595]
# epoch: 500, [Discriminator :: d_loss: 0.612199], [ Generator :: loss: 0.889744]
# epoch: 600, [Discriminator :: d_loss: 0.613871], [ Generator :: loss: 0.675448]
# epoch: 700, [Discriminator :: d_loss: 0.560199], [ Generator :: loss: 0.782950]
# epoch: 800, [Discriminator :: d_loss: 0.624913], [ Generator :: loss: 0.651096]
# epoch: 900, [Discriminator :: d_loss: 0.611495], [ Generator :: loss: 0.478067]
# epoch: 1000, [Discriminator :: d_loss: 0.619920], [ Generator :: loss: 1.002611]
# epoch: 1100, [Discriminator :: d_loss: 0.631744], [ Generator :: loss: 0.961256]
# epoch: 1200, [Discriminator :: d_loss: 0.566461], [ Generator :: loss: 0.668870]
# epoch: 1300, [Discriminator :: d_loss: 0.638809], [ Generator :: loss: 0.687704]
# epoch: 1400, [Discriminator :: d_loss: 0.496109], [ Generator :: loss: 1.372734]
# epoch: 1500, [Discriminator :: d_loss: 0.598051], [ Generator :: loss: 0.834899]
# epoch: 1600, [Discriminator :: d_loss: 0.539769], [ Generator :: loss: 1.102819]
# epoch: 1700, [Discriminator :: d_loss: 0.647351], [ Generator :: loss: 0.907527]
# epoch: 1800, [Discriminator :: d_loss: 0.501311], [ Generator :: loss: 0.939795]
# epoch: 1900, [Discriminator :: d_loss: 0.500363], [ Generator :: loss: 0.915743]
# epoch: 2000, [Discriminator :: d_loss: 0.500068], [ Generator :: loss: 0.902288]
# epoch: 2100, [Discriminator :: d_loss: 0.527903], [ Generator :: loss: 0.761134]
# epoch: 2200, [Discriminator :: d_loss: 0.451396], [ Generator :: loss: 1.081272]
# epoch: 2300, [Discriminator :: d_loss: 0.539605], [ Generator :: loss: 1.104660]
# epoch: 2400, [Discriminator :: d_loss: 0.661792], [ Generator :: loss: 0.974487]
# epoch: 2500, [Discriminator :: d_loss: 0.601430], [ Generator :: loss: 0.660896]
# epoch: 2600, [Discriminator :: d_loss: 0.506979], [ Generator :: loss: 0.777969]
# epoch: 2700, [Discriminator :: d_loss: 0.562139], [ Generator :: loss: 0.910322]
# epoch: 2800, [Discriminator :: d_loss: 0.662401], [ Generator :: loss: 1.242882]
# epoch: 2900, [Discriminator :: d_loss: 0.468196], [ Generator :: loss: 0.937413]
# epoch: 3000, [Discriminator :: d_loss: 0.531950], [ Generator :: loss: 0.999642]
# epoch: 3100, [Discriminator :: d_loss: 0.531896], [ Generator :: loss: 1.151598]
# epoch: 3200, [Discriminator :: d_loss: 0.647739], [ Generator :: loss: 0.761171]
# epoch: 3300, [Discriminator :: d_loss: 0.645419], [ Generator :: loss: 0.962643]
# epoch: 3400, [Discriminator :: d_loss: 0.639944], [ Generator :: loss: 0.824390]
# epoch: 3500, [Discriminator :: d_loss: 0.549835], [ Generator :: loss: 1.111444]
# epoch: 3600, [Discriminator :: d_loss: 0.575264], [ Generator :: loss: 1.409361]
# epoch: 3700, [Discriminator :: d_loss: 0.606005], [ Generator :: loss: 1.103787]
# epoch: 3800, [Discriminator :: d_loss: 0.664445], [ Generator :: loss: 1.157039]
# epoch: 3900, [Discriminator :: d_loss: 0.707630], [ Generator :: loss: 1.055336]
# epoch: 4000, [Discriminator :: d_loss: 0.898338], [ Generator :: loss: 1.060022]
# epoch: 4100, [Discriminator :: d_loss: 0.699438], [ Generator :: loss: 0.684280]
# epoch: 4200, [Discriminator :: d_loss: 0.621418], [ Generator :: loss: 0.949600]
# epoch: 4300, [Discriminator :: d_loss: 0.619704], [ Generator :: loss: 1.159792]
# epoch: 4400, [Discriminator :: d_loss: 0.616956], [ Generator :: loss: 0.888332]
# epoch: 4500, [Discriminator :: d_loss: 0.680551], [ Generator :: loss: 0.837788]
# epoch: 4600, [Discriminator :: d_loss: 0.557852], [ Generator :: loss: 1.295112]
# epoch: 4700, [Discriminator :: d_loss: 0.651533], [ Generator :: loss: 0.867596]
# epoch: 4800, [Discriminator :: d_loss: 0.595103], [ Generator :: loss: 1.056545]
# epoch: 4900, [Discriminator :: d_loss: 0.667310], [ Generator :: loss: 0.918264]
# epoch: 5000, [Discriminator :: d_loss: 0.563242], [ Generator :: loss: 0.847372]
# epoch: 5100, [Discriminator :: d_loss: 0.621464], [ Generator :: loss: 0.944202]
# epoch: 5200, [Discriminator :: d_loss: 0.597543], [ Generator :: loss: 0.939810]
# epoch: 5300, [Discriminator :: d_loss: 0.597261], [ Generator :: loss: 0.879241]
# epoch: 5400, [Discriminator :: d_loss: 0.566903], [ Generator :: loss: 1.018651]
# epoch: 5500, [Discriminator :: d_loss: 0.606588], [ Generator :: loss: 1.168794]
# epoch: 5600, [Discriminator :: d_loss: 0.587481], [ Generator :: loss: 0.982703]
# epoch: 5700, [Discriminator :: d_loss: 0.647622], [ Generator :: loss: 0.787695]
# epoch: 5800, [Discriminator :: d_loss: 0.588060], [ Generator :: loss: 1.120949]
# epoch: 5900, [Discriminator :: d_loss: 0.624089], [ Generator :: loss: 0.861669]
# epoch: 6000, [Discriminator :: d_loss: 0.776353], [ Generator :: loss: 0.890364]
# epoch: 6100, [Discriminator :: d_loss: 0.657183], [ Generator :: loss: 1.094952]
# epoch: 6200, [Discriminator :: d_loss: 0.601173], [ Generator :: loss: 0.700969]
# epoch: 6300, [Discriminator :: d_loss: 0.623336], [ Generator :: loss: 1.044887]
# epoch: 6400, [Discriminator :: d_loss: 0.683125], [ Generator :: loss: 0.950014]
# epoch: 6500, [Discriminator :: d_loss: 0.605165], [ Generator :: loss: 0.841554]
# epoch: 6600, [Discriminator :: d_loss: 0.679271], [ Generator :: loss: 0.933952]
# epoch: 6700, [Discriminator :: d_loss: 0.524760], [ Generator :: loss: 0.933204]
# epoch: 6800, [Discriminator :: d_loss: 0.752078], [ Generator :: loss: 0.745407]
# epoch: 6900, [Discriminator :: d_loss: 0.738582], [ Generator :: loss: 0.809397]
# epoch: 7000, [Discriminator :: d_loss: 0.688828], [ Generator :: loss: 0.992175]
# epoch: 7100, [Discriminator :: d_loss: 0.639283], [ Generator :: loss: 0.885197]
# epoch: 7200, [Discriminator :: d_loss: 0.656783], [ Generator :: loss: 0.878840]
# epoch: 7300, [Discriminator :: d_loss: 0.783866], [ Generator :: loss: 0.922867]
# epoch: 7400, [Discriminator :: d_loss: 0.597277], [ Generator :: loss: 1.186000]
# epoch: 7500, [Discriminator :: d_loss: 0.631896], [ Generator :: loss: 0.912018]
# epoch: 7600, [Discriminator :: d_loss: 0.568787], [ Generator :: loss: 0.857655]
# epoch: 7700, [Discriminator :: d_loss: 0.653468], [ Generator :: loss: 0.894510]
# epoch: 7800, [Discriminator :: d_loss: 0.666793], [ Generator :: loss: 0.839762]
# epoch: 7900, [Discriminator :: d_loss: 0.544603], [ Generator :: loss: 0.845503]
# epoch: 8000, [Discriminator :: d_loss: 0.611759], [ Generator :: loss: 0.841632]
# epoch: 8100, [Discriminator :: d_loss: 0.631717], [ Generator :: loss: 1.005406]
# epoch: 8200, [Discriminator :: d_loss: 0.607384], [ Generator :: loss: 0.895924]
# epoch: 8300, [Discriminator :: d_loss: 0.650320], [ Generator :: loss: 0.817322]
# epoch: 8400, [Discriminator :: d_loss: 0.573028], [ Generator :: loss: 1.122584]
# epoch: 8500, [Discriminator :: d_loss: 0.642156], [ Generator :: loss: 0.834552]
# epoch: 8600, [Discriminator :: d_loss: 0.670315], [ Generator :: loss: 1.020037]
# epoch: 8700, [Discriminator :: d_loss: 0.643795], [ Generator :: loss: 1.010692]
# epoch: 8800, [Discriminator :: d_loss: 0.718579], [ Generator :: loss: 0.712751]
# epoch: 8900, [Discriminator :: d_loss: 0.639242], [ Generator :: loss: 0.905104]
# epoch: 9000, [Discriminator :: d_loss: 0.695801], [ Generator :: loss: 0.881591]
# epoch: 9100, [Discriminator :: d_loss: 0.587824], [ Generator :: loss: 1.044308]
# epoch: 9200, [Discriminator :: d_loss: 0.718379], [ Generator :: loss: 0.796193]
# epoch: 9300, [Discriminator :: d_loss: 0.670207], [ Generator :: loss: 0.711100]
# epoch: 9400, [Discriminator :: d_loss: 0.614394], [ Generator :: loss: 1.088729]
# epoch: 9500, [Discriminator :: d_loss: 0.663691], [ Generator :: loss: 0.840805]
# epoch: 9600, [Discriminator :: d_loss: 0.709282], [ Generator :: loss: 0.936293]
# epoch: 9700, [Discriminator :: d_loss: 0.657912], [ Generator :: loss: 0.812542]
# epoch: 9800, [Discriminator :: d_loss: 0.719607], [ Generator :: loss: 0.838043]
# epoch: 9900, [Discriminator :: d_loss: 0.535995], [ Generator :: loss: 0.870113]
# epoch: 10000, [Discriminator :: d_loss: 0.655748], [ Generator :: loss: 0.871369]
# epoch: 10100, [Discriminator :: d_loss: 0.651150], [ Generator :: loss: 0.886760]
# epoch: 10200, [Discriminator :: d_loss: 0.647326], [ Generator :: loss: 0.806713]
# epoch: 10300, [Discriminator :: d_loss: 0.649041], [ Generator :: loss: 1.025271]
# epoch: 10400, [Discriminator :: d_loss: 0.634366], [ Generator :: loss: 1.040505]
# epoch: 10500, [Discriminator :: d_loss: 0.643324], [ Generator :: loss: 0.976600]
# epoch: 10600, [Discriminator :: d_loss: 0.613348], [ Generator :: loss: 0.902383]
# epoch: 10700, [Discriminator :: d_loss: 0.683460], [ Generator :: loss: 0.828258]
# epoch: 10800, [Discriminator :: d_loss: 0.658748], [ Generator :: loss: 0.677108]
# epoch: 10900, [Discriminator :: d_loss: 0.649457], [ Generator :: loss: 0.828924]
# epoch: 11000, [Discriminator :: d_loss: 0.655456], [ Generator :: loss: 0.816144]
# epoch: 11100, [Discriminator :: d_loss: 0.607529], [ Generator :: loss: 1.053115]
# epoch: 11200, [Discriminator :: d_loss: 0.656015], [ Generator :: loss: 0.827966]
# epoch: 11300, [Discriminator :: d_loss: 0.663013], [ Generator :: loss: 0.743729]
# epoch: 11400, [Discriminator :: d_loss: 0.606671], [ Generator :: loss: 0.881897]
# epoch: 11500, [Discriminator :: d_loss: 0.685497], [ Generator :: loss: 0.920912]
# epoch: 11600, [Discriminator :: d_loss: 0.597801], [ Generator :: loss: 0.696998]
# epoch: 11700, [Discriminator :: d_loss: 0.652406], [ Generator :: loss: 0.741153]
# epoch: 11800, [Discriminator :: d_loss: 0.734446], [ Generator :: loss: 0.767785]
# epoch: 11900, [Discriminator :: d_loss: 0.728124], [ Generator :: loss: 0.802221]
# epoch: 12000, [Discriminator :: d_loss: 0.724599], [ Generator :: loss: 0.720483]
# epoch: 12100, [Discriminator :: d_loss: 0.668586], [ Generator :: loss: 1.062608]
# epoch: 12200, [Discriminator :: d_loss: 0.635248], [ Generator :: loss: 0.869968]
# epoch: 12300, [Discriminator :: d_loss: 0.761307], [ Generator :: loss: 0.790367]
# epoch: 12400, [Discriminator :: d_loss: 0.572871], [ Generator :: loss: 0.832889]
# epoch: 12500, [Discriminator :: d_loss: 0.677772], [ Generator :: loss: 0.802381]
# epoch: 12600, [Discriminator :: d_loss: 0.665488], [ Generator :: loss: 0.693029]
# epoch: 12700, [Discriminator :: d_loss: 0.723524], [ Generator :: loss: 0.752799]
# epoch: 12800, [Discriminator :: d_loss: 0.633665], [ Generator :: loss: 0.848180]
# epoch: 12900, [Discriminator :: d_loss: 0.677617], [ Generator :: loss: 0.642928]
# epoch: 13000, [Discriminator :: d_loss: 0.593694], [ Generator :: loss: 0.969604]
# epoch: 13100, [Discriminator :: d_loss: 0.656626], [ Generator :: loss: 0.997088]
# epoch: 13200, [Discriminator :: d_loss: 0.732016], [ Generator :: loss: 0.931686]
# epoch: 13300, [Discriminator :: d_loss: 0.853568], [ Generator :: loss: 0.598316]
# epoch: 13400, [Discriminator :: d_loss: 0.639710], [ Generator :: loss: 0.775662]
# epoch: 13500, [Discriminator :: d_loss: 0.674443], [ Generator :: loss: 0.831694]
# epoch: 13600, [Discriminator :: d_loss: 0.716792], [ Generator :: loss: 0.911222]
# epoch: 13700, [Discriminator :: d_loss: 0.631552], [ Generator :: loss: 0.766713]
# epoch: 13800, [Discriminator :: d_loss: 0.703282], [ Generator :: loss: 0.805460]
# epoch: 13900, [Discriminator :: d_loss: 0.733239], [ Generator :: loss: 0.788640]
# epoch: 14000, [Discriminator :: d_loss: 0.736135], [ Generator :: loss: 0.812894]
# epoch: 14100, [Discriminator :: d_loss: 0.623750], [ Generator :: loss: 1.049944]
# epoch: 14200, [Discriminator :: d_loss: 0.637246], [ Generator :: loss: 0.959123]
# epoch: 14300, [Discriminator :: d_loss: 0.619928], [ Generator :: loss: 0.872018]
# epoch: 14400, [Discriminator :: d_loss: 0.675505], [ Generator :: loss: 0.884102]
# epoch: 14500, [Discriminator :: d_loss: 0.693624], [ Generator :: loss: 0.944583]
# epoch: 14600, [Discriminator :: d_loss: 0.711824], [ Generator :: loss: 0.910777]
# epoch: 14700, [Discriminator :: d_loss: 0.620748], [ Generator :: loss: 0.846581]
# epoch: 14800, [Discriminator :: d_loss: 0.685611], [ Generator :: loss: 0.838805]
# epoch: 14900, [Discriminator :: d_loss: 0.636613], [ Generator :: loss: 0.848429]
# epoch: 15000, [Discriminator :: d_loss: 0.612392], [ Generator :: loss: 1.003984]
# epoch: 15100, [Discriminator :: d_loss: 0.645314], [ Generator :: loss: 0.832925]
# epoch: 15200, [Discriminator :: d_loss: 0.705151], [ Generator :: loss: 0.973186]
# epoch: 15300, [Discriminator :: d_loss: 0.623697], [ Generator :: loss: 0.763443]
# epoch: 15400, [Discriminator :: d_loss: 0.638220], [ Generator :: loss: 0.749897]
# epoch: 15500, [Discriminator :: d_loss: 0.642637], [ Generator :: loss: 0.878819]
# epoch: 15600, [Discriminator :: d_loss: 0.784720], [ Generator :: loss: 0.633137]
# epoch: 15700, [Discriminator :: d_loss: 0.743577], [ Generator :: loss: 0.927437]
# epoch: 15800, [Discriminator :: d_loss: 0.813794], [ Generator :: loss: 0.994037]
# epoch: 15900, [Discriminator :: d_loss: 0.647686], [ Generator :: loss: 0.749339]
# epoch: 16000, [Discriminator :: d_loss: 0.654049], [ Generator :: loss: 0.705712]
# epoch: 16100, [Discriminator :: d_loss: 0.664158], [ Generator :: loss: 0.800208]
# epoch: 16200, [Discriminator :: d_loss: 0.820134], [ Generator :: loss: 0.807186]
# epoch: 16300, [Discriminator :: d_loss: 0.571709], [ Generator :: loss: 0.802605]
# epoch: 16400, [Discriminator :: d_loss: 0.746521], [ Generator :: loss: 0.875134]
# epoch: 16500, [Discriminator :: d_loss: 0.628669], [ Generator :: loss: 0.803886]
# epoch: 16600, [Discriminator :: d_loss: 0.600493], [ Generator :: loss: 0.862135]
# epoch: 16700, [Discriminator :: d_loss: 0.751464], [ Generator :: loss: 0.930236]
# epoch: 16800, [Discriminator :: d_loss: 0.770219], [ Generator :: loss: 1.013571]
# epoch: 16900, [Discriminator :: d_loss: 0.660562], [ Generator :: loss: 0.911364]
# epoch: 17000, [Discriminator :: d_loss: 0.566588], [ Generator :: loss: 0.867909]
# epoch: 17100, [Discriminator :: d_loss: 0.648423], [ Generator :: loss: 0.878444]
# epoch: 17200, [Discriminator :: d_loss: 0.692837], [ Generator :: loss: 0.854083]
# epoch: 17300, [Discriminator :: d_loss: 0.688170], [ Generator :: loss: 0.738033]
# epoch: 17400, [Discriminator :: d_loss: 0.698771], [ Generator :: loss: 0.913980]
# epoch: 17500, [Discriminator :: d_loss: 0.577263], [ Generator :: loss: 0.991692]
# epoch: 17600, [Discriminator :: d_loss: 0.634822], [ Generator :: loss: 0.978939]
# epoch: 17700, [Discriminator :: d_loss: 0.653142], [ Generator :: loss: 0.782759]
# epoch: 17800, [Discriminator :: d_loss: 0.664407], [ Generator :: loss: 0.704580]
# epoch: 17900, [Discriminator :: d_loss: 0.663946], [ Generator :: loss: 0.946499]
# epoch: 18000, [Discriminator :: d_loss: 0.649306], [ Generator :: loss: 0.873913]
# epoch: 18100, [Discriminator :: d_loss: 0.625913], [ Generator :: loss: 0.911565]
# epoch: 18200, [Discriminator :: d_loss: 0.624276], [ Generator :: loss: 0.773459]
# epoch: 18300, [Discriminator :: d_loss: 0.601274], [ Generator :: loss: 0.706174]
# epoch: 18400, [Discriminator :: d_loss: 0.640658], [ Generator :: loss: 0.832884]
# epoch: 18500, [Discriminator :: d_loss: 0.736934], [ Generator :: loss: 0.751940]
# epoch: 18600, [Discriminator :: d_loss: 0.678840], [ Generator :: loss: 0.594934]
# epoch: 18700, [Discriminator :: d_loss: 0.583375], [ Generator :: loss: 0.882705]
# epoch: 18800, [Discriminator :: d_loss: 0.693632], [ Generator :: loss: 0.803295]
# epoch: 18900, [Discriminator :: d_loss: 0.728053], [ Generator :: loss: 0.768864]
# epoch: 19000, [Discriminator :: d_loss: 0.674590], [ Generator :: loss: 0.750229]
# epoch: 19100, [Discriminator :: d_loss: 0.606212], [ Generator :: loss: 0.944159]
# epoch: 19200, [Discriminator :: d_loss: 0.787241], [ Generator :: loss: 0.758816]
# epoch: 19300, [Discriminator :: d_loss: 0.767210], [ Generator :: loss: 0.859756]
# epoch: 19400, [Discriminator :: d_loss: 0.621738], [ Generator :: loss: 0.967728]
# epoch: 19500, [Discriminator :: d_loss: 0.635482], [ Generator :: loss: 0.693012]
# epoch: 19600, [Discriminator :: d_loss: 0.708660], [ Generator :: loss: 0.901681]
# epoch: 19700, [Discriminator :: d_loss: 0.659421], [ Generator :: loss: 0.836552]
# epoch: 19800, [Discriminator :: d_loss: 0.717641], [ Generator :: loss: 0.849224]
# epoch: 19900, [Discriminator :: d_loss: 0.761650], [ Generator :: loss: 0.688624]
# epoch: 20000, [Discriminator :: d_loss: 0.676764], [ Generator :: loss: 1.046980]
# epoch: 20100, [Discriminator :: d_loss: 0.694823], [ Generator :: loss: 0.666046]
# epoch: 20200, [Discriminator :: d_loss: 0.748109], [ Generator :: loss: 0.892302]
# epoch: 20300, [Discriminator :: d_loss: 0.640606], [ Generator :: loss: 0.840682]
# epoch: 20400, [Discriminator :: d_loss: 0.731604], [ Generator :: loss: 0.691663]
# epoch: 20500, [Discriminator :: d_loss: 0.619688], [ Generator :: loss: 0.862705]
# epoch: 20600, [Discriminator :: d_loss: 0.651180], [ Generator :: loss: 0.822059]
# epoch: 20700, [Discriminator :: d_loss: 0.675767], [ Generator :: loss: 0.820514]
# epoch: 20800, [Discriminator :: d_loss: 0.757384], [ Generator :: loss: 0.710339]
# epoch: 20900, [Discriminator :: d_loss: 0.582658], [ Generator :: loss: 0.889333]
# epoch: 21000, [Discriminator :: d_loss: 0.643368], [ Generator :: loss: 0.954721]
# epoch: 21100, [Discriminator :: d_loss: 0.628045], [ Generator :: loss: 0.722584]
# epoch: 21200, [Discriminator :: d_loss: 0.690944], [ Generator :: loss: 0.766917]
# epoch: 21300, [Discriminator :: d_loss: 0.658775], [ Generator :: loss: 0.847827]
# epoch: 21400, [Discriminator :: d_loss: 0.678593], [ Generator :: loss: 0.970775]
# epoch: 21500, [Discriminator :: d_loss: 0.634584], [ Generator :: loss: 0.777468]
# epoch: 21600, [Discriminator :: d_loss: 0.701662], [ Generator :: loss: 0.835842]
# epoch: 21700, [Discriminator :: d_loss: 0.623366], [ Generator :: loss: 0.763333]
# epoch: 21800, [Discriminator :: d_loss: 0.653807], [ Generator :: loss: 0.888235]
# epoch: 21900, [Discriminator :: d_loss: 0.605302], [ Generator :: loss: 0.919836]
# epoch: 22000, [Discriminator :: d_loss: 0.695363], [ Generator :: loss: 0.786456]
# epoch: 22100, [Discriminator :: d_loss: 0.680405], [ Generator :: loss: 0.653648]
# epoch: 22200, [Discriminator :: d_loss: 0.535194], [ Generator :: loss: 0.892525]
# epoch: 22300, [Discriminator :: d_loss: 0.616277], [ Generator :: loss: 0.825698]
# epoch: 22400, [Discriminator :: d_loss: 0.686201], [ Generator :: loss: 0.830781]
# epoch: 22500, [Discriminator :: d_loss: 0.592217], [ Generator :: loss: 0.853650]
# epoch: 22600, [Discriminator :: d_loss: 0.635340], [ Generator :: loss: 0.794057]
# epoch: 22700, [Discriminator :: d_loss: 0.622048], [ Generator :: loss: 0.848513]
# epoch: 22800, [Discriminator :: d_loss: 0.778306], [ Generator :: loss: 0.883109]
# epoch: 22900, [Discriminator :: d_loss: 0.690713], [ Generator :: loss: 0.805701]
# epoch: 23000, [Discriminator :: d_loss: 0.582287], [ Generator :: loss: 0.940433]
# epoch: 23100, [Discriminator :: d_loss: 0.745013], [ Generator :: loss: 0.759287]
# epoch: 23200, [Discriminator :: d_loss: 0.738180], [ Generator :: loss: 0.815655]
# epoch: 23300, [Discriminator :: d_loss: 0.673656], [ Generator :: loss: 0.759607]
# epoch: 23400, [Discriminator :: d_loss: 0.623173], [ Generator :: loss: 0.835015]
# epoch: 23500, [Discriminator :: d_loss: 0.624750], [ Generator :: loss: 0.934247]
# epoch: 23600, [Discriminator :: d_loss: 0.683142], [ Generator :: loss: 0.815114]
# epoch: 23700, [Discriminator :: d_loss: 0.662605], [ Generator :: loss: 0.761119]
# epoch: 23800, [Discriminator :: d_loss: 0.622203], [ Generator :: loss: 0.941271]
# epoch: 23900, [Discriminator :: d_loss: 0.606330], [ Generator :: loss: 0.977420]
# epoch: 24000, [Discriminator :: d_loss: 0.736025], [ Generator :: loss: 0.695329]
# epoch: 24100, [Discriminator :: d_loss: 0.658728], [ Generator :: loss: 0.780814]
# epoch: 24200, [Discriminator :: d_loss: 0.691751], [ Generator :: loss: 0.838552]
# epoch: 24300, [Discriminator :: d_loss: 0.715378], [ Generator :: loss: 0.640468]
# epoch: 24400, [Discriminator :: d_loss: 0.652649], [ Generator :: loss: 0.922961]
# epoch: 24500, [Discriminator :: d_loss: 0.593258], [ Generator :: loss: 1.010574]
# epoch: 24600, [Discriminator :: d_loss: 0.569499], [ Generator :: loss: 0.922169]
# epoch: 24700, [Discriminator :: d_loss: 0.621441], [ Generator :: loss: 0.877854]
# epoch: 24800, [Discriminator :: d_loss: 0.754318], [ Generator :: loss: 0.876519]
# epoch: 24900, [Discriminator :: d_loss: 0.663846], [ Generator :: loss: 0.725004]
# epoch: 25000, [Discriminator :: d_loss: 0.671697], [ Generator :: loss: 0.768299]
# epoch: 25100, [Discriminator :: d_loss: 0.565863], [ Generator :: loss: 0.913152]
# epoch: 25200, [Discriminator :: d_loss: 0.679109], [ Generator :: loss: 0.651426]
# epoch: 25300, [Discriminator :: d_loss: 0.651556], [ Generator :: loss: 0.753323]
# epoch: 25400, [Discriminator :: d_loss: 0.651014], [ Generator :: loss: 0.865370]
# epoch: 25500, [Discriminator :: d_loss: 0.685939], [ Generator :: loss: 0.696215]
# epoch: 25600, [Discriminator :: d_loss: 0.549949], [ Generator :: loss: 0.918858]
# epoch: 25700, [Discriminator :: d_loss: 0.624070], [ Generator :: loss: 0.983965]
# epoch: 25800, [Discriminator :: d_loss: 0.667069], [ Generator :: loss: 0.895878]
# epoch: 25900, [Discriminator :: d_loss: 0.592324], [ Generator :: loss: 0.920709]
# epoch: 26000, [Discriminator :: d_loss: 0.688812], [ Generator :: loss: 0.863077]
# epoch: 26100, [Discriminator :: d_loss: 0.628204], [ Generator :: loss: 0.875372]
# epoch: 26200, [Discriminator :: d_loss: 0.608945], [ Generator :: loss: 0.894537]
# epoch: 26300, [Discriminator :: d_loss: 0.635880], [ Generator :: loss: 0.859196]
# epoch: 26400, [Discriminator :: d_loss: 0.647124], [ Generator :: loss: 1.027662]
# epoch: 26500, [Discriminator :: d_loss: 0.663069], [ Generator :: loss: 0.884303]
# epoch: 26600, [Discriminator :: d_loss: 0.706336], [ Generator :: loss: 0.880536]
# epoch: 26700, [Discriminator :: d_loss: 0.536685], [ Generator :: loss: 0.819765]
# epoch: 26800, [Discriminator :: d_loss: 0.672637], [ Generator :: loss: 0.879208]
# epoch: 26900, [Discriminator :: d_loss: 0.720603], [ Generator :: loss: 0.905464]
# epoch: 27000, [Discriminator :: d_loss: 0.558942], [ Generator :: loss: 1.081125]
# epoch: 27100, [Discriminator :: d_loss: 0.730895], [ Generator :: loss: 0.827503]
# epoch: 27200, [Discriminator :: d_loss: 0.607654], [ Generator :: loss: 0.868154]
# epoch: 27300, [Discriminator :: d_loss: 0.714607], [ Generator :: loss: 0.794544]
# epoch: 27400, [Discriminator :: d_loss: 0.605290], [ Generator :: loss: 0.883611]
# epoch: 27500, [Discriminator :: d_loss: 0.724804], [ Generator :: loss: 0.922011]
# epoch: 27600, [Discriminator :: d_loss: 0.670748], [ Generator :: loss: 0.766252]
# epoch: 27700, [Discriminator :: d_loss: 0.625541], [ Generator :: loss: 0.682680]
# epoch: 27800, [Discriminator :: d_loss: 0.760350], [ Generator :: loss: 0.654246]
# epoch: 27900, [Discriminator :: d_loss: 0.626334], [ Generator :: loss: 0.893844]
# epoch: 28000, [Discriminator :: d_loss: 0.679180], [ Generator :: loss: 0.910298]
# epoch: 28100, [Discriminator :: d_loss: 0.751170], [ Generator :: loss: 0.904625]
# epoch: 28200, [Discriminator :: d_loss: 0.641337], [ Generator :: loss: 0.825761]
# epoch: 28300, [Discriminator :: d_loss: 0.571130], [ Generator :: loss: 0.845880]
# epoch: 28400, [Discriminator :: d_loss: 0.619756], [ Generator :: loss: 0.843772]
# epoch: 28500, [Discriminator :: d_loss: 0.571770], [ Generator :: loss: 0.845182]
# epoch: 28600, [Discriminator :: d_loss: 0.607304], [ Generator :: loss: 0.778738]
# epoch: 28700, [Discriminator :: d_loss: 0.593338], [ Generator :: loss: 0.928687]
# epoch: 28800, [Discriminator :: d_loss: 0.743748], [ Generator :: loss: 0.806473]
# epoch: 28900, [Discriminator :: d_loss: 0.622090], [ Generator :: loss: 0.853489]
# epoch: 29000, [Discriminator :: d_loss: 0.670875], [ Generator :: loss: 0.799304]
# epoch: 29100, [Discriminator :: d_loss: 0.621155], [ Generator :: loss: 0.986714]
# epoch: 29200, [Discriminator :: d_loss: 0.640406], [ Generator :: loss: 0.767963]
# epoch: 29300, [Discriminator :: d_loss: 0.682521], [ Generator :: loss: 0.795598]
# epoch: 29400, [Discriminator :: d_loss: 0.781637], [ Generator :: loss: 0.841937]
# epoch: 29500, [Discriminator :: d_loss: 0.599255], [ Generator :: loss: 0.778451]
# epoch: 29600, [Discriminator :: d_loss: 0.736871], [ Generator :: loss: 0.720266]
# epoch: 29700, [Discriminator :: d_loss: 0.605874], [ Generator :: loss: 0.807916]
# epoch: 29800, [Discriminator :: d_loss: 0.689840], [ Generator :: loss: 0.759182]
# epoch: 29900, [Discriminator :: d_loss: 0.579763], [ Generator :: loss: 1.010581]

# %%
# !pwd
# !tar cvf pic.tar *.png
# Out:
# /content
# mnist_00000.png
# mnist_00100.png
# mnist_00200.png
# mnist_00300.png
# mnist_00400.png
# mnist_00500.png
# mnist_00600.png
# mnist_00700.png
# mnist_00800.png
# mnist_00900.png
# mnist_01000.png
# mnist_01100.png
# mnist_01200.png
# mnist_01300.png
# mnist_01400.png
# mnist_01500.png
# mnist_01600.png
# mnist_01700.png
# mnist_01800.png
# mnist_01900.png
# mnist_02000.png
# mnist_02100.png
# mnist_02200.png
# mnist_02300.png
# mnist_02400.png
# mnist_02500.png
# mnist_02600.png
# mnist_02700.png
# mnist_02800.png
# mnist_02900.png
# mnist_03000.png
# mnist_03100.png
# mnist_03200.png
# mnist_03300.png
# mnist_03400.png
# mnist_03500.png
# mnist_03600.png
# mnist_03700.png
# mnist_03800.png
# mnist_03900.png
# mnist_04000.png
# mnist_04100.png
# mnist_04200.png
# mnist_04300.png
# mnist_04400.png
# mnist_04500.png
# mnist_04600.png
# mnist_04700.png
# mnist_04800.png
# mnist_04900.png
# mnist_05000.png
# mnist_05100.png
# mnist_05200.png
# mnist_05300.png
# mnist_05400.png
# mnist_05500.png
# mnist_05600.png
# mnist_05700.png
# mnist_05800.png
# mnist_05900.png
# mnist_06000.png
# mnist_06100.png
# mnist_06200.png
# mnist_06300.png
# mnist_06400.png
# mnist_06500.png
# mnist_06600.png
# mnist_06700.png
# mnist_06800.png
# mnist_06900.png
# mnist_07000.png
# mnist_07100.png
# mnist_07200.png
# mnist_07300.png
# mnist_07400.png
# mnist_07500.png
# mnist_07600.png
# mnist_07700.png
# mnist_07800.png
# mnist_07900.png
# mnist_08000.png
# mnist_08100.png
# mnist_08200.png
# mnist_08300.png
# mnist_08400.png
# mnist_08500.png
# mnist_08600.png
# mnist_08700.png
# mnist_08800.png
# mnist_08900.png
# mnist_09000.png
# mnist_09100.png
# mnist_09200.png
# mnist_09300.png
# mnist_09400.png
# mnist_09500.png
# mnist_09600.png
# mnist_09700.png
# mnist_09800.png
# mnist_09900.png
# mnist_10000.png
# mnist_10100.png
# mnist_10200.png
# mnist_10300.png
# mnist_10400.png
# mnist_10500.png
# mnist_10600.png
# mnist_10700.png
# mnist_10800.png
# mnist_10900.png
# mnist_11000.png
# mnist_11100.png
# mnist_11200.png
# mnist_11300.png
# mnist_11400.png
# mnist_11500.png
# mnist_11600.png
# mnist_11700.png
# mnist_11800.png
# mnist_11900.png
# mnist_12000.png
# mnist_12100.png
# mnist_12200.png
# mnist_12300.png
# mnist_12400.png
# mnist_12500.png
# mnist_12600.png
# mnist_12700.png
# mnist_12800.png
# mnist_12900.png
# mnist_13000.png
# mnist_13100.png
# mnist_13200.png
# mnist_13300.png
# mnist_13400.png
# mnist_13500.png
# mnist_13600.png
# mnist_13700.png
# mnist_13800.png
# mnist_13900.png
# mnist_14000.png
# mnist_14100.png
# mnist_14200.png
# mnist_14300.png
# mnist_14400.png
# mnist_14500.png
# mnist_14600.png
# mnist_14700.png
# mnist_14800.png
# mnist_14900.png
# mnist_15000.png
# mnist_15100.png
# mnist_15200.png
# mnist_15300.png
# mnist_15400.png
# mnist_15500.png
# mnist_15600.png
# mnist_15700.png
# mnist_15800.png
# mnist_15900.png
# mnist_16000.png
# mnist_16100.png
# mnist_16200.png
# mnist_16300.png
# mnist_16400.png
# mnist_16500.png
# mnist_16600.png
# mnist_16700.png
# mnist_16800.png
# mnist_16900.png
# mnist_17000.png
# mnist_17100.png
# mnist_17200.png
# mnist_17300.png
# mnist_17400.png
# mnist_17500.png
# mnist_17600.png
# mnist_17700.png
# mnist_17800.png
# mnist_17900.png
# mnist_18000.png
# mnist_18100.png
# mnist_18200.png
# mnist_18300.png
# mnist_18400.png
# mnist_18500.png
# mnist_18600.png
# mnist_18700.png
# mnist_18800.png
# mnist_18900.png
# mnist_19000.png
# mnist_19100.png
# mnist_19200.png
# mnist_19300.png
# mnist_19400.png
# mnist_19500.png
# mnist_19600.png
# mnist_19700.png
# mnist_19800.png
# mnist_19900.png
# mnist_20000.png
# mnist_20100.png
# mnist_20200.png
# mnist_20300.png
# mnist_20400.png
# mnist_20500.png
# mnist_20600.png
# mnist_20700.png
# mnist_20800.png
# mnist_20900.png
# mnist_21000.png
# mnist_21100.png
# mnist_21200.png
# mnist_21300.png
# mnist_21400.png
# mnist_21500.png
# mnist_21600.png
# mnist_21700.png
# mnist_21800.png
# mnist_21900.png
# mnist_22000.png
# mnist_22100.png
# mnist_22200.png
# mnist_22300.png
# mnist_22400.png
# mnist_22500.png
# mnist_22600.png
# mnist_22700.png
# mnist_22800.png
# mnist_22900.png
# mnist_23000.png
# mnist_23100.png
# mnist_23200.png
# mnist_23300.png
# mnist_23400.png
# mnist_23500.png
# mnist_23600.png
# mnist_23700.png
# mnist_23800.png
# mnist_23900.png
# mnist_24000.png
# mnist_24100.png
# mnist_24200.png
# mnist_24300.png
# mnist_24400.png
# mnist_24500.png
# mnist_24600.png
# mnist_24700.png
# mnist_24800.png
# mnist_24900.png
# mnist_25000.png
# mnist_25100.png
# mnist_25200.png
# mnist_25300.png
# mnist_25400.png
# mnist_25500.png
# mnist_25600.png
# mnist_25700.png
# mnist_25800.png
# mnist_25900.png
# mnist_26000.png
# mnist_26100.png
# mnist_26200.png
# mnist_26300.png
# mnist_26400.png
# mnist_26500.png
# mnist_26600.png
# mnist_26700.png
# mnist_26800.png
# mnist_26900.png
# mnist_27000.png
# mnist_27100.png
# mnist_27200.png
# mnist_27300.png
# mnist_27400.png
# mnist_27500.png
# mnist_27600.png
# mnist_27700.png
# mnist_27800.png
# mnist_27900.png
# mnist_28000.png
# mnist_28100.png
# mnist_28200.png
# mnist_28300.png
# mnist_28400.png
# mnist_28500.png
# mnist_28600.png
# mnist_28700.png
# mnist_28800.png
# mnist_28900.png
# mnist_29000.png
# mnist_29100.png
# mnist_29200.png
# mnist_29300.png
# mnist_29400.png
# mnist_29500.png
# mnist_29600.png
# mnist_29700.png
# mnist_29800.png
# mnist_29900.png

# %%
# !ls pic.tar
# Out:
# pic.tar
